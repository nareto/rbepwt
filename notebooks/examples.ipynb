# %%
# %matplotlib inline
import matplotlib.pyplot as plt
#import pylab as plt
import rbepwt
import numpy as np
plt.rcParams['figure.figsize'] = (12, 12)

# %%
grad = rbepwt.Image()
grad.load('../pickled/gradient64-gradpath-bior4.4-12levels')
grad.show()
# Out:
# /Users/renato/anaconda/lib/python3.5/site-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
print(grad.label_img.max(),grad.segmentation.estimate_perimeter())
grad.show_segmentation()
# Out:
# 4 513
# /Users/renato/anaconda/lib/python3.5/site-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
grad.load('../pickled/gradient64-gradpath-bior4.4-12levels')
grad.rbepwt.threshold_coefs(700)
grad.decode_rbepwt()
grad.show_decoded()
grad.error()
# Out:
# --DECODING: finished working on level 12
#
# --DECODING: finished working on level 11
#
# --DECODING: finished working on level 10
#
# --DECODING: finished working on level 9
#
# --DECODING: finished working on level 8
#
# --DECODING: finished working on level 7
#
# --DECODING: finished working on level 6
#
# --DECODING: finished working on level 5
#
# --DECODING: finished working on level 4
#
# --DECODING: finished working on level 3
#
# --DECODING: finished working on level 2
#
# --DECODING: finished working on level 1
# NONZEROCOEFS: 700
# PSNR: 103.609854
# SSIM: 0.631667
# /Users/renato/anaconda/lib/python3.5/site-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
grad.load('../pickled/gradient64-gradpath-bior4.4-12levels')
grad.rbepwt.threshold_coefs(500)
grad.decode_rbepwt()
grad.show_decoded()
grad.error()
# Out:
# --DECODING: finished working on level 12
#
# --DECODING: finished working on level 11
#
# --DECODING: finished working on level 10
#
# --DECODING: finished working on level 9
#
# --DECODING: finished working on level 8
#
# --DECODING: finished working on level 7
#
# --DECODING: finished working on level 6
#
# --DECODING: finished working on level 5
#
# --DECODING: finished working on level 4
#
# --DECODING: finished working on level 3
#
# --DECODING: finished working on level 2
#
# --DECODING: finished working on level 1
# NONZEROCOEFS: 500
# PSNR: 73.036647
# SSIM: 0.605624
# /Users/renato/anaconda/lib/python3.5/site-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
grad.load('../pickled/gradient64-gradpath-bior4.4-12levels')
grad.rbepwt.threshold_coefs(250)
grad.decode_rbepwt()
grad.show_decoded()
grad.error()
# Out:
# --DECODING: finished working on level 12
#
# --DECODING: finished working on level 11
#
# --DECODING: finished working on level 10
#
# --DECODING: finished working on level 9
#
# --DECODING: finished working on level 8
#
# --DECODING: finished working on level 7
#
# --DECODING: finished working on level 6
#
# --DECODING: finished working on level 5
#
# --DECODING: finished working on level 4
#
# --DECODING: finished working on level 3
#
# --DECODING: finished working on level 2
#
# --DECODING: finished working on level 1
# NONZEROCOEFS: 250
# PSNR: 12.431733
# SSIM: 0.501619
# /Users/renato/anaconda/lib/python3.5/site-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
house_easy = rbepwt.Image()
house_easy.load('../pickled/house256-easypath-bior4.4-12levels')
house_easy.show()
# Out:
# /Users/renato/anaconda/lib/python3.5/site-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
print(house_easy.label_img.max(),house_easy.segmentation.estimate_perimeter())
house_easy.show_segmentation()
# Out:
# 71 5731
# /Users/renato/anaconda/lib/python3.5/site-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
house_easy.rbepwt.threshold_coefs(4096)
house_easy.decode_rbepwt()
house_easy.show_decoded()
house_easy.psnr()
# Out:
# --DECODING: finished working on level 12
#
# --DECODING: finished working on level 11
#
# --DECODING: finished working on level 10
#
# --DECODING: finished working on level 9
#
# --DECODING: finished working on level 8
#
# --DECODING: finished working on level 7
#
# --DECODING: finished working on level 6
#
# --DECODING: finished working on level 5
#
# --DECODING: finished working on level 4
#
# --DECODING: finished working on level 3
#
# --DECODING: finished working on level 2
#
# --DECODING: finished working on level 1
# NONZEROCOEFS: 4096
# /Users/renato/anaconda/lib/python3.5/site-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
# 68.164542333740499

# %%
house_easy.rbepwt.threshold_coefs(2048)
house_easy.decode_rbepwt()
house_easy.show_decoded()
house_easy.psnr()
# Out:
# --DECODING: finished working on level 12
#
# --DECODING: finished working on level 11
#
# --DECODING: finished working on level 10
#
# --DECODING: finished working on level 9
#
# --DECODING: finished working on level 8
#
# --DECODING: finished working on level 7
#
# --DECODING: finished working on level 6
#
# --DECODING: finished working on level 5
#
# --DECODING: finished working on level 4
#
# --DECODING: finished working on level 3
#
# --DECODING: finished working on level 2
#
# --DECODING: finished working on level 1
# NONZEROCOEFS: 2048
# /Users/renato/anaconda/lib/python3.5/site-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
# 47.685566848506546

# %%
house_easy.rbepwt.threshold_coefs(1024)
house_easy.decode_rbepwt()
house_easy.show_decoded()
house_easy.psnr()
# Out:
# --DECODING: finished working on level 12
#
# --DECODING: finished working on level 11
#
# --DECODING: finished working on level 10
#
# --DECODING: finished working on level 9
#
# --DECODING: finished working on level 8
#
# --DECODING: finished working on level 7
#
# --DECODING: finished working on level 6
#
# --DECODING: finished working on level 5
#
# --DECODING: finished working on level 4
#
# --DECODING: finished working on level 3
#
# --DECODING: finished working on level 2
#
# --DECODING: finished working on level 1
# NONZEROCOEFS: 1024
# /Users/renato/anaconda/lib/python3.5/site-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
# 30.109196884922355

# %%
house_grad = rbepwt.Image()
house_grad.load('../pickled/house256-gradpath-bior4.4-12levels')
#house_grad.show()

# %%
house_grad.rbepwt.threshold_coefs(2048)
house_grad.decode_rbepwt()
house_grad.show_decoded()
house_grad.psnr()
# Out:
# --DECODING: finished working on level 12
#
# --DECODING: finished working on level 11
#
# --DECODING: finished working on level 10
#
# --DECODING: finished working on level 9
#
# --DECODING: finished working on level 8
#
# --DECODING: finished working on level 7
#
# --DECODING: finished working on level 6
#
# --DECODING: finished working on level 5
#
# --DECODING: finished working on level 4
#
# --DECODING: finished working on level 3
#
# --DECODING: finished working on level 2
#
# --DECODING: finished working on level 1
# NONZEROCOEFS: 2048
# /Users/renato/anaconda/lib/python3.5/site-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
# 48.835358712955909

# %%
house_grad.rbepwt.threshold_coefs(1024)
house_grad.decode_rbepwt()
house_grad.show_decoded()
house_grad.psnr()
# Out:
# --DECODING: finished working on level 12
#
# --DECODING: finished working on level 11
#
# --DECODING: finished working on level 10
#
# --DECODING: finished working on level 9
#
# --DECODING: finished working on level 8
#
# --DECODING: finished working on level 7
#
# --DECODING: finished working on level 6
#
# --DECODING: finished working on level 5
#
# --DECODING: finished working on level 4
#
# --DECODING: finished working on level 3
#
# --DECODING: finished working on level 2
#
# --DECODING: finished working on level 1
# NONZEROCOEFS: 1024
# /Users/renato/anaconda/lib/python3.5/site-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
# 31.040869135472079

# %%
peppers_grad = rbepwt.Image()
peppers_grad.load('../pickled/peppers256-gradpath-bior4.4-12levels')
#peppers_grad.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-05a999ac91ff> in <module>()
#       1 peppers_grad = rbepwt.Image()
# ----> 2 peppers_grad.load('../pickled/peppers256-gradpath-bior4.4-12levels')
#       3 #peppers_grad.load('../pickled/peppers256-gradpath-bior4.4-12levels')
#       4 #peppers_grad.show()
#
# /Users/renato/ownCloud/phd/code/epwt/rbepwt/notebooks/rbepwt.py in load(self, filepath)
#     187     def load(self,filepath):
#     188         f = open(filepath,'rb')
# --> 189         tmpdict = pickle.load(f)
#     190         f.close()
#     191         self.__dict__.update(tmpdict)
#
# /Users/renato/anaconda/lib/python3.5/site-packages/matplotlib/figure.py in __setstate__(self, state)
#    1434             allnums = plt.get_fignums()
#    1435             num = max(allnums) + 1 if allnums else 1
# ...

# %%
ls ..
# Out:
# #rbepwt.py#          check_threshold.py~  psnr-range.py
# __pycache__/         felzenszwalb.py*     psnr-range.py~
# check_decode.py      img@                 rbepwt.py
# check_decode.py~     notebooks/           rbepwt.py~
# check_encoding.py    pickled/             test.py~
# check_encoding.py~   prova                threshold_test.py~
# check_threshold.py   psnr-range/
