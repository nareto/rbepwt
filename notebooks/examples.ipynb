# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import rbepwt
plt.rcParams['figure.figsize'] = (12, 12)

# %%
grad = rbepwt.Image()
grad.load('../pickled/gradient64-bior4.4-12levels')
grad.show()
# Out:
# /Users/renato/anaconda/lib/python3.5/site-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
print(grad.label_img.max(),grad.segmentation.estimate_perimeter())
grad.show_segmentation()
# Out:
# 8 640
# /Users/renato/anaconda/lib/python3.5/site-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
grad.load('../pickled/gradient64-bior4.4-12levels')
grad.rbepwt.threshold_coefs(500)
grad.decode_rbepwt()
grad.show_decoded()
grad.psnr()
# Out:
# --DECODING: finished working on level 12
#
# --DECODING: finished working on level 11
#
# --DECODING: finished working on level 10
#
# --DECODING: finished working on level 9
#
# --DECODING: finished working on level 8
#
# --DECODING: finished working on level 7
#
# --DECODING: finished working on level 6
#
# --DECODING: finished working on level 5
#
# --DECODING: finished working on level 4
#
# --DECODING: finished working on level 3
#
# --DECODING: finished working on level 2
#
# --DECODING: finished working on level 1
# NONZEROCOEFS: 500
# /Users/renato/anaconda/lib/python3.5/site-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
# 72.725655766448497

# %%
house = rbepwt.Image()
house.load('../pickled/house256-bior4.4-12levels')
house.show()
# Out:
# /Users/renato/anaconda/lib/python3.5/site-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
print(house.label_img.max(),house.segmentation.estimate_perimeter())
house.show_segmentation()
# Out:
# 71 5731
# /Users/renato/anaconda/lib/python3.5/site-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
house.rbepwt.threshold_coefs(4096)
house.decode_rbepwt()
house.show_decoded()
house.psnr()
# Out:
# --DECODING: finished working on level 12
#
# --DECODING: finished working on level 11
#
# --DECODING: finished working on level 10
#
# --DECODING: finished working on level 9
#
# --DECODING: finished working on level 8
#
# --DECODING: finished working on level 7
#
# --DECODING: finished working on level 6
#
# --DECODING: finished working on level 5
#
# --DECODING: finished working on level 4
#
# --DECODING: finished working on level 3
#
# --DECODING: finished working on level 2
#
# --DECODING: finished working on level 1
# NONZEROCOEFS: 4096
# /Users/renato/anaconda/lib/python3.5/site-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
# 68.164542333740499

# %%
house.rbepwt.threshold_coefs(2048)
house.decode_rbepwt()
house.show_decoded()
house.psnr()
# Out:
# --DECODING: finished working on level 12
#
# --DECODING: finished working on level 11
#
# --DECODING: finished working on level 10
#
# --DECODING: finished working on level 9
#
# --DECODING: finished working on level 8
#
# --DECODING: finished working on level 7
#
# --DECODING: finished working on level 6
#
# --DECODING: finished working on level 5
#
# --DECODING: finished working on level 4
#
# --DECODING: finished working on level 3
#
# --DECODING: finished working on level 2
#
# --DECODING: finished working on level 1
# NONZEROCOEFS: 2048
# /Users/renato/anaconda/lib/python3.5/site-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
# 47.685566848506546

# %%
house.rbepwt.threshold_coefs(1024)
house.decode_rbepwt()
house.show_decoded()
house.psnr()
# Out:
# --DECODING: finished working on level 12
#
# --DECODING: finished working on level 11
#
# --DECODING: finished working on level 10
#
# --DECODING: finished working on level 9
#
# --DECODING: finished working on level 8
#
# --DECODING: finished working on level 7
#
# --DECODING: finished working on level 6
#
# --DECODING: finished working on level 5
#
# --DECODING: finished working on level 4
#
# --DECODING: finished working on level 3
#
# --DECODING: finished working on level 2
#
# --DECODING: finished working on level 1
# NONZEROCOEFS: 1024
# /Users/renato/anaconda/lib/python3.5/site-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
# 30.109196884922355

# %%
house = rbepwt.Image()
house.load('../pickled/house256-bior4.4-12levels')
house.show()
