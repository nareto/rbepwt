# %%
# %matplotlib inline
import rbepwt
import numpy as np
import pandas as pd

# %%
levels = 3

i = rbepwt.Image()
#i.read('img/cameraman.png')
#i.read('img/gradient64.jpg')
i.read('img/sampleimg4x4.png')
#i.segment(scale=2,sigma=0,min_size=1)
i.segment(scale=200,sigma=0.8,min_size=10)
i.encode_rbepwt(levels,'db1')
i.rbepwt.show()
#i.rbepwt.show_wavelets()
#i.rbepwt.threshold_coeffs(1)
i.decode_rbepwt()
#i.show()
i.show_decoded()
#i.rbepwt.show_wavelets()
for key,wav in i.rbepwt.wavelet_details.items():
    print("Wavelet coefs at level %d: %s" % (key,wav))
print("Wavelet approx coefs: %s" % i.rbepwt.region_collection_dict[levels + 1].values)
i.rbepwt.threshold_coefs(4)
for key,wav in i.rbepwt.wavelet_details.items():
    print("Wavelet coefs at level %d: %s" % (key,wav))
print("Wavelet approx coefs: %s" % i.rbepwt.region_collection_dict[levels + 1].values)
i.decode_rbepwt()
i.show_decoded()
#i.rbepwt.show_wavelets()
#i.rbepwt.show_wavelets()
#i.show_segmentation()
# Out:
# /Users/renato/ownCloud/phd/code/epwt/rbepwt/notebooks/rbepwt.py:157: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if values != None and len(base_points) != len(values):
# /Users/renato/ownCloud/phd/code/epwt/rbepwt/notebooks/rbepwt.py:162: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if values == None or len(values) == 0:
# /Users/renato/anaconda/lib/python3.5/site-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-ecff2b49023e> in <module>()
#      11 #i.rbepwt.show_wavelets()
#      12 #i.rbepwt.threshold_coeffs(1)
# ---> 13 i.decode_rbepwt()
#      14 #i.show()
#      15 i.show_decoded()
#
# /Users/renato/ownCloud/phd/code/epwt/rbepwt/notebooks/rbepwt.py in decode_rbepwt(self)
#      61
#      62     def decode_rbepwt(self):
# ---> 63         self.decoded_region_collection = self.rbepwt.decode()
#      64         self.decoded_img = np.zeros_like(self.img)
#      65         for coord,value in self.decoded_region_collection.points.items():
#
# /Users/renato/ownCloud/phd/code/epwt/rbepwt/notebooks/rbepwt.py in decode(self)
#     543             wdetail,wapprox = self.wavelet_details[level], cur_region_collection.values
#     544             #ipdb.set_trace()
# --> 545             values = pywt.idwt(wapprox, wdetail, wavelet)
#     546             upper_region_collection = self.region_collection_dict[level]
#     547             new_region_collection = cur_region_collection.expand(values,upper_region_collection,wavelet)
#
# _pywt.pyx in _pywt.idwt (pywt/src/_pywt.c:16049)()
#
# _pywt.pyx in _pywt.idwt_single (pywt/src/_pywt.c:17667)()
#
# ValueError: Coefficients arrays must have the same size.
