# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import rbepwt
plt.rcParams['figure.figsize'] = (12, 12)

# %%
grad_easy = rbepwt.Image()
grad_easy.load('../pickled/gradient64-easypath-bior4.4-12levels')

# %%
grad_easy.rbepwt.show()
# Out:
# /Users/renato/anaconda/lib/python3.5/site-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
grad_grad = rbepwt.Image()
grad_grad.load('../pickled/gradient64-gradpath-bior4.4-12levels')

# %%
grad_grad.rbepwt.show()
# Out:
# /Users/renato/anaconda/lib/python3.5/site-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
